# %%
import pandas as pd

# %%
df_emp = pd.read_csv('employees.csv')

# %%
df_salary = pd.read_json('salary.json')

# %%
df_emp
# Out:
#     eno           ename    hiredate
# 0     1        John Doe  2020-01-15
# 1     2      Jane Smith  2019-03-22
# 2     3     Bob Johnson  2021-07-30
# 3     4  Alice Williams  2018-12-05
# 4     5   Charlie Brown  2022-05-14
# 5     6     Emily Davis  2021-04-12
# 6     7  Michael Miller  2019-09-10
# 7     8    Sarah Wilson  2020-11-01
# 8     9  David Martinez  2023-02-20
# 9    10    Laura Taylor  2022-08-17
# 10   11  James Anderson  2017-06-19
# 11   12    Karen Thomas  2020-10-14
# 12   13  Robert Jackson  2018-03-29
# 13   14      Mary White  2021-05-06
# 14   15  William Harris  2019-12-12
# 15   16  Patricia Lewis  2023-03-05
# 16   17      Daniel Lee  2022-01-23
# 17   18     Susan Clark  2020-09-18
# 18   19     George Hall  2021-11-07
# 19   20   Jessica Young  2022-04-25

# %%
import pandas as pd
import pytest
from sqlalchemy import create_engine
mysql_engine = create_engine('mysql+pymysql://root:Admin%40143@localhost:3308/demo')

# %%
df_expected = pd.read_csv('employees.csv')
query = """select * from staging_employees"""
df_actual = pd.read_sql(query,mysql_engine)

# %%
df_expected
# Out:
#     eno           ename    hiredate
# 0     1        John Doe  2020-01-15
# 1     2      Jane Smith  2019-03-22
# 2     3     Bob Johnson  2021-07-30
# 3     4  Alice Williams  2018-12-05
# 4     5   Charlie Brown  2022-05-14
# 5     6     Emily Davis  2021-04-12
# 6     7  Michael Miller  2019-09-10
# 7     8    Sarah Wilson  2020-11-01
# 8     9  David Martinez  2023-02-20
# 9    10    Laura Taylor  2022-08-17
# 10   11  James Anderson  2017-06-19
# 11   12    Karen Thomas  2020-10-14
# 12   13  Robert Jackson  2018-03-29
# 13   14      Mary White  2021-05-06
# 14   15  William Harris  2019-12-12
# 15   16  Patricia Lewis  2023-03-05
# 16   17      Daniel Lee  2022-01-23
# 17   18     Susan Clark  2020-09-18
# 18   19     George Hall  2021-11-07
# 19   20   Jessica Young  2022-04-25

# %%
df_actual
# Out:
#     eno           ename    hiredate
# 0     1        John Doe  2020-01-15
# 1     2      Jane Smith  2019-03-22
# 2     3     Bob Johnson  2021-07-30
# 3     4  Alice Williams  2018-12-05
# 4     5   Charlie Brown  2022-05-14
# 5     6     Emily Davis  2021-04-12
# 6     7  Michael Miller  2019-09-10
# 7     8    Sarah Wilson  2020-11-01
# 8     9  David Martinez  2023-02-20
# 9    10    Laura Taylor  2022-08-17
# 10   11  James Anderson  2017-06-19
# 11   12    Karen Thomas  2020-10-14
# 12   13  Robert Jackson  2018-03-29
# 13   14      Mary White  2021-05-06
# 14   15  William Harris  2019-12-12
# 15   16  Patricia Lewis  2023-03-05
# 16   17      Daniel Lee  2022-01-23
# 17   18     Susan Clark  2020-09-18
# 18   19     George Hall  2021-11-07
# 19   20   Jessica Young  2022-04-25

# %%
query_expected = """select upper(ename) as upper_name from staging_employees"""
df_expected = pd.read_sql(query_expected, mysql_engine)
query_actual = """select upper_name from employees_detail"""
df_actual = pd.read_sql(query_actual,mysql_engine)

# %%
df_expected['upper_name'].dtype
# Out:
# dtype('O')

# %%
df_actual
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 df_actual.dtype
#
# File C:\Python310\lib\site-packages\pandas\core\generic.py:6204, in NDFrame.__getattr__(self, name)
#    6197 if (
#    6198     name not in self._internal_names_set
#    6199     and name not in self._metadata
#    6200     and name not in self._accessors
#    6201     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202 ):
#    6203     return self[name]
# -> 6204 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
df_expected['upper_name'].dtype
# Out:
# dtype('O')

# %%
df_actual['upper_name'].dtype
# Out:
# dtype('O')
